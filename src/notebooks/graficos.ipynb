# %%
from sklearn.datasets import load_iris, load_boston
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Algunas configuraciones de los paquetes
pd.set_option("display.max_rows", 500) # Cuántas filas de los DataFrames nos "escupe" pandas en el Notebook
sns.set(color_codes=True)

import warnings
warnings.filterwarnings("ignore")

# %%
coches_df = pd.read_csv(r'C:\Users\desardi131\Desktop\desardi131\The_Bridge_Data_Science\Python\Proyectos\EDA\Datasets\coches_fil.csv')
coches_df.head()
# Out:
#            id                                                url      region  \
# 0  7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...      auburn
# 1  7316871204  https://bham.craigslist.org/ctd/d/birmingham-2...  birmingham
# 2  7316735728  https://bham.craigslist.org/ctd/d/bessemer-200...  birmingham
# 3  7314893113  https://bham.craigslist.org/ctd/d/powder-sprin...  birmingham
# 4  7314847158  https://bham.craigslist.org/cto/d/birmingham-t...  birmingham
#
#    price  year manufacturer       model  condition    cylinders    fuel  ...  \
# 0  14000  2012        honda     odyssey  excellent  6 cylinders     gas  ...
# 1   6995  2011   volkswagen   jetta sel  excellent  5 cylinders     gas  ...
# 2   3950  2008          kia  spectra ex  excellent  4 cylinders     gas  ...
# 3   8900  2013       toyota       prius  excellent  4 cylinders  hybrid  ...
# 4  10800  2013       toyota       camry  excellent  4 cylinders  hybrid  ...
#
# ...

# %%
grafica_df = coches_df.loc[:,['price','year','cylinders','odometer', 'reliability']]
grafica_df.loc[grafica_df['cylinders'] == 'other', 'cylinders'] = '0'

# %%
grafica_df[grafica_df['cylinders'] == '0']
# Out:
#        price  year cylinders  odometer  reliability
# 431     4995  2013         0   67260.0         82.0
# 1301    4400  2011         0   37000.0         82.0
# 1320   18495  2017         0   24018.0         82.0
# 1367   13500  2017         0   46920.0         89.0
# 1427   13500  2017         0   46920.0         89.0
# 1477   18495  2017         0   24018.0         82.0
# 1479    8000  2016         0  214000.0         91.0
# 1486   13500  2017         0   46920.0         89.0
# 1511   13500  2017         0   46920.0         89.0
# 1537   13500  2017         0   46920.0         89.0
# 2129   17000  2011         0   25939.0         82.0
# 2432    5000  2012         0   42000.0         82.0
# 2528    5990  2013         0   74864.0         82.0
# 2643    4999  2012         0   67000.0         82.0
# 2675    6499  2013         0   83477.0         82.0
# 2754   12991  2016         0   38733.0         82.0
# 2846   18500  2015         0   22510.0         91.0
# ...

# %%
grafica_df['cylinders'] = grafica_df['cylinders'].str[0].apply(pd.to_numeric)

# %%
media_c= grafica_df[grafica_df['cylinders'] != 0]

# %%
sol_media =media_c['cylinders'].mean()
sol_media.round(2)
# Out:
# 4.45

# %%
grafica_df.loc[grafica_df['cylinders'] == 0, 'cylinders'] = sol_media.round(2)

# %%
grafica_df['cylinders'].unique()
# Out:
# array([6.  , 5.  , 4.  , 3.  , 4.45])

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(coches_df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(coches_df['price'], kde=False, color = 'b')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.pairplot(grafica_df,
kind = "reg");

# %%
plt.figure(figsize=(10,10))
sns.heatmap(grafica_df.corr(),
vmin = -1,
vmax = 1,
cmap = sns.diverging_palette(145, 280, s=85, l=25, n=7),
annot = True,
square = True,
linewidth = .5);

# %%
mejores = coches_df['model'].value_counts().head()
