# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %%
df_vehicles = pd.read_csv('Datasets/vehicles.csv')
df_vehicles
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
df_vehicles.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# ...

# %%
df_vehicles.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
df_vehicles[df_vehicles.columns].isnull().all()
# Out:
# id              False
# url             False
# region          False
# region_url      False
# price           False
# year            False
# manufacturer    False
# model           False
# condition       False
# cylinders       False
# fuel            False
# odometer        False
# title_status    False
# transmission    False
# VIN             False
# drive           False
# size            False
# type            False
# paint_color     False
# image_url       False
# description     False
# county           True
# state           False
# lat             False
# long            False
# posting_date    False
# dtype: bool

# %%
df_vehicles.drop('county',axis=1, inplace=True)

# %%
df_vehicles
# Out:
#                 id                                                url  \
# 0       7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1       7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2       7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3       7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4       7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#                         region                         region_url  price  \
# ...

# %%
df_vehicles[df_vehicles.columns].isnull().any()
# Out:
# id              False
# url             False
# region          False
# region_url      False
# price           False
# year             True
# manufacturer     True
# model            True
# condition        True
# cylinders        True
# fuel             True
# odometer         True
# title_status     True
# transmission     True
# VIN              True
# drive            True
# size             True
# type             True
# paint_color      True
# image_url        True
# description      True
# state           False
# lat              True
# long             True
# posting_date     True
# dtype: bool

# %%
df_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
# ...

# %%
len(df_vehicles[df_vehicles['image_url'].notnull()])
# Out:
# 426812

# %%
df_vehicles = df_vehicles[df_vehicles['image_url'].isnull()==False]

# %%
df_vehicles
# Out:
#                 id                                                url  \
# 27      7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 28      7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 29      7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 30      7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
df_vehicles = df_vehicles[df_vehicles['condition'].isnull()==False]

# %%
df_vehicles = df_vehicles[df_vehicles['cylinders'].isnull()==False]
df_vehicles
# Out:
#                 id                                                url  \
# 27      7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 28      7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 29      7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 30      7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426868  7301843288  https://wyoming.craigslist.org/ctd/d/frederick...
# 426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
df_vehicles = df_vehicles[df_vehicles['title_status'].isnull() == False]

# %%
df_vehicles= df_vehicles[df_vehicles['type'].isnull()==False]
df_vehicles
# Out:
#                 id                                                url  \
# 27      7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 28      7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 29      7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 30      7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426864  7301949196  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
df_vehicles = df_vehicles[df_vehicles['manufacturer'].isnull()==False]

# %%
df_vehicles = df_vehicles[df_vehicles['odometer'].isnull()==False]
df_vehicles
# Out:
#                 id                                                url  \
# 27      7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 28      7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 29      7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 30      7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426864  7301949196  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
pp_empiezo= df_vehicles.head()

# %%
pp_empiezo
# Out:
#             id                                                url  region  \
# 27  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 28  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 29  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 30  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...  auburn
# 31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...  auburn
#
#                        region_url  price    year manufacturer  \
# 27  https://auburn.craigslist.org  33590  2014.0          gmc
# 28  https://auburn.craigslist.org  22590  2010.0    chevrolet
# 29  https://auburn.craigslist.org  39590  2020.0    chevrolet
# 30  https://auburn.craigslist.org  30990  2017.0       toyota
# 31  https://auburn.craigslist.org  15000  2013.0         ford
#
#                        model  condition    cylinders  ... drive       size  \
# ...

# %%
pp_empiezo.to_csv('Datasets/pp_empiezo.csv',index=False)

# %%
df_vehicles = df_vehicles[df_vehicles['cylinders'].str[0]!='1']
df_vehicles
# Out:
#                 id                                                url  \
# 27      7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 28      7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 29      7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 30      7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 31      7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...            ...                                                ...
# 426864  7301949196  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# ...

# %%
df_vehicles.reset_index(inplace=True)

# %%
df_vehicles
# Out:
#          index          id                                                url  \
# 0           27  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1           28  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2           29  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3           30  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...        ...         ...                                                ...
# 147374  426864  7301949196  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147375  426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147376  426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147377  426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147378  426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
# ...

# %%
df_vehicles.to_csv('Datasets/vehicles_limp.csv',index=False)

# %%
prueba = pd.read_csv('C:/Users/desardi131/Desktop/desardi131/The_Bridge_Data_Science/Python\Proyectos/EDA\Datasets/vehicles_limp.csv')
prueba
# Out:
#          index          id                                                url  \
# 0           27  7316814884  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 1           28  7316814758  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 2           29  7316814989  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 3           30  7316743432  https://auburn.craigslist.org/ctd/d/auburn-uni...
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...        ...         ...                                                ...
# 147374  426864  7301949196  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147375  426866  7301949190  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147376  426874  7301591199  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147377  426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 147378  426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
# ...

# %%
prueba.state.nunique()
# Out:
# 51

# %%
edades = {'23 años':25000,
        '20 años'	: 16479}

# para salario de 25000 dolares:
dinero = ((25000*20)/100)*4
dinero
# Out:
# 20000.0

# %%
prueba_fil = prueba[prueba['price']<20000]
prueba_fil
# Out:
#          index          id                                                url  \
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# 17          55  7314560853  https://auburn.craigslist.org/cto/d/auburn-200...
# 20          59  7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 31          73  7312144944  https://auburn.craigslist.org/cto/d/dadeville-...
# 37          86  7310644616  https://auburn.craigslist.org/cto/d/auburn-chr...
# ...        ...         ...                                                ...
# 147360  426808  7302963673  https://wyoming.craigslist.org/cto/d/jackson-2...
# 147361  426809  7302963273  https://wyoming.craigslist.org/cto/d/jackson-1...
# 147367  426831  7302384818  https://wyoming.craigslist.org/cto/d/cheyenne-...
# 147368  426833  7302338378  https://wyoming.craigslist.org/cto/d/kirby-jag...
# 147369  426836  7302301268  https://wyoming.craigslist.org/ctd/d/dassel-20...
#
# ...

# %%
fabricantes = prueba_fil['manufacturer'].unique()

# %%
df_fiabilidad = pd.read_csv('C:/Users/desardi131/Desktop/desardi131/The_Bridge_Data_Science/Python/Proyectos/EDA/Datasets/fiabilidad.csv')
df_fiabilidad
# Out:
#              title  puntos
# 0            Lexus      95
# 1           Subaru      93
# 2           Toyota      91
# 3       Mitsubishi      89
# 4              Kia      89
# 5           Suzuki      89
# 6          Hyundai      87
# 7            Honda      87
# 8            Mazda      85
# 9             Seat      85
# 10           Dacia      85
# 11           Skoda      84
# 12          Nissan      82
# 13  DS Automobiles      82
# 14      Volkswagen      82
# 15           Smart      82
# 16         Peugeot      82
# 17   Mercedes-Benz      82
# 18             BMW      82
# 19            Mini      82
# 20            Ford      80
# 21         Citroën      80
# 22            Audi      80
# 23           Volvo      80
# 24         Renault      80
# 25       SsangYong      80
# 26         Porsche      76
# 27            Opel      76
# 28            Fiat      76
# 29            Jeep      72
# 30          Lancia      68
# 31       Chevrolet      68
# 32          Jaguar      68
# ...

# %%
df_fiabilidad['title'] = df_fiabilidad['title'].str.lower()

# %%
df_fiabilidad
# Out:
#              title  puntos
# 0            lexus      95
# 1           subaru      93
# 2           toyota      91
# 3       mitsubishi      89
# 4              kia      89
# 5           suzuki      89
# 6          hyundai      87
# 7            honda      87
# 8            mazda      85
# 9             seat      85
# 10           dacia      85
# 11           skoda      84
# 12          nissan      82
# 13  ds automobiles      82
# 14      volkswagen      82
# 15           smart      82
# 16         peugeot      82
# 17   mercedes-benz      82
# 18             bmw      82
# 19            mini      82
# 20            ford      80
# 21         citroën      80
# 22            audi      80
# 23           volvo      80
# 24         renault      80
# 25       ssangyong      80
# 26         porsche      76
# 27            opel      76
# 28            fiat      76
# 29            jeep      72
# 30          lancia      68
# 31       chevrolet      68
# 32          jaguar      68
# ...

# %%
df_fiabilidad.loc[:,('title')].iloc[34]
#= 'alfa-romeo'
# Out:
# 'alfa romeo'

# %%
lista_fabricantes = list(fabricantes)
lista_fabricantes
# Out:
# ['ford',
#  'honda',
#  'dodge',
#  'chrysler',
#  'subaru',
#  'toyota',
#  'mercedes-benz',
#  'chevrolet',
#  'jeep',
#  'bmw',
#  'volkswagen',
#  'mazda',
#  'porsche',
#  'lexus',
#  'nissan',
#  'kia',
#  'gmc',
#  'rover',
#  'ram',
#  'acura',
#  'mitsubishi',
#  'infiniti',
#  'hyundai',
#  'fiat',
#  'cadillac',
#  'lincoln',
#  'audi',
#  'jaguar',
#  'saturn',
#  'volvo',
#  'alfa-romeo',
#  'buick',
#  'pontiac',
#  'mini',
#  'harley-davidson',
#  'mercury',
#  'datsun',
#  'land rover',
#  'tesla',
#  'ferrari']

# %%
lista_fiabilidad = df_fiabilidad['title'].to_list()

# %%
for i in lista_fabricantes:
    if i in lista_fiabilidad:
        print(True)

    else:
        print(False)
# Out:
# True
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# False
# True
# False
# True
# True
# False
# False
# True
# True
# False
# True
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False

# %%
dic_fabri = {'lista_fabricantes' : lista_fabricantes}
dic_fiab = {'lista_fiabilidad': lista_fiabilidad}

# %%
df_fiab = pd.DataFrame(dic_fiab)
df_fabri = pd.DataFrame(dic_fabri)

# %%
df_fiab = df_fiab[df_fiab.isin(lista_fabricantes) == True].dropna()

# %%
filtro_1 = df_fiab['lista_fiabilidad'].to_list()
filtro_1
# Out:
# ['lexus',
#  'subaru',
#  'toyota',
#  'mitsubishi',
#  'kia',
#  'hyundai',
#  'honda',
#  'mazda',
#  'nissan',
#  'volkswagen',
#  'mercedes-benz',
#  'bmw',
#  'mini',
#  'ford',
#  'audi',
#  'volvo',
#  'porsche',
#  'fiat',
#  'jeep',
#  'chevrolet',
#  'jaguar',
#  'land rover',
#  'tesla']

# %%
prueba_fil = prueba_fil[prueba_fil['manufacturer'].isin(filtro_1) == True]

# %%
df_fiab.reset_index(inplace=True)#.drop('index',axis=1,inplace=True)

# %%
df_fiab.drop('index',axis=1,inplace=True)

# %%
prueba_fil
# Out:
#          index          id                                                url  \
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# 17          55  7314560853  https://auburn.craigslist.org/cto/d/auburn-200...
# 20          59  7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 39          95  7309798041  https://auburn.craigslist.org/cto/d/auburn-200...
# 51         119  7306407989  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...        ...         ...                                                ...
# 147356  426793  7303112347  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 147360  426808  7302963673  https://wyoming.craigslist.org/cto/d/jackson-2...
# 147361  426809  7302963273  https://wyoming.craigslist.org/cto/d/jackson-1...
# 147367  426831  7302384818  https://wyoming.craigslist.org/cto/d/cheyenne-...
# 147368  426833  7302338378  https://wyoming.craigslist.org/cto/d/kirby-jag...
#
# ...

# %%
mas_fiables =  df_fiab.iloc[:16]
filtro_2 = mas_fiables['lista_fiabilidad'].to_list()

# %%
prueba_fil =prueba_fil[prueba_fil['manufacturer'].isin(filtro_2)==True]

# %%
prueba_fil['model'].value_counts()
# Out:
# f-150                    1348
# camry                    1089
# accord                    981
# civic                     921
# altima                    856
#                          ...
# e550 e-550                  1
# c300 c-300 luxury awd       1
# insight lx                  1
# r 320 r320 bluetec          1
# rx& gls sport               1
# Name: model, Length: 6349, dtype: int64

# %%
prueba_fil
# Out:
#          index          id                                                url  \
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# 17          55  7314560853  https://auburn.craigslist.org/cto/d/auburn-200...
# 20          59  7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 39          95  7309798041  https://auburn.craigslist.org/cto/d/auburn-200...
# 51         119  7306407989  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...        ...         ...                                                ...
# 147315  426720  7305220802  https://wyoming.craigslist.org/cto/d/cheyenne-...
# 147319  426737  7304360046  https://wyoming.craigslist.org/cto/d/laramie-2...
# 147326  426746  7303723154  https://wyoming.craigslist.org/cto/d/pinedale-...
# 147333  426762  7303456231  https://wyoming.craigslist.org/cto/d/laramie-1...
# 147367  426831  7302384818  https://wyoming.craigslist.org/cto/d/cheyenne-...
#
# ...

# %%
prueba_fil['year'] = prueba_fil['year'].astype('int32')
# Out:
# c:\Users\desardi131\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
prueba_fil
# Out:
#          index          id                                                url  \
# 4           31  7316356412  https://auburn.craigslist.org/cto/d/auburn-uni...
# 17          55  7314560853  https://auburn.craigslist.org/cto/d/auburn-200...
# 20          59  7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 39          95  7309798041  https://auburn.craigslist.org/cto/d/auburn-200...
# 51         119  7306407989  https://auburn.craigslist.org/cto/d/auburn-uni...
# ...        ...         ...                                                ...
# 147315  426720  7305220802  https://wyoming.craigslist.org/cto/d/cheyenne-...
# 147319  426737  7304360046  https://wyoming.craigslist.org/cto/d/laramie-2...
# 147326  426746  7303723154  https://wyoming.craigslist.org/cto/d/pinedale-...
# 147333  426762  7303456231  https://wyoming.craigslist.org/cto/d/laramie-1...
# 147367  426831  7302384818  https://wyoming.craigslist.org/cto/d/cheyenne-...
#
# ...

# %%
# el promedio de un coche son unos 12 años, por eso vamos a retirar los vehiculos con mas de 15 años y menos de 3 ya que en estos casos los vehiculos no son considerados viejos y su valor aun es demasiado alto 

prueba_fil=  prueba_fil[(prueba_fil['year'] >2007) & (prueba_fil['year']<2019)]

# %%
prueba_fil= prueba_fil[prueba_fil['condition'].isin(['excellent','like new','new'])]

# %%
prueba_fil =  prueba_fil[prueba_fil['price']>1000]

# %%
prueba_fil= prueba_fil[~prueba_fil['type'].isin(['bus','truck','convertible'])]

# %%
prueba_fil = prueba_fil[prueba_fil['cylinders'] !='8 cylinders']

# %%
prueba_fil.reset_index(inplace=True)

# %%
df_def = prueba_fil.drop(['level_0','index'],axis=1)

# %%
df_def = df_def.drop(['region_url','posting_date'],axis=1)

# %%
df_def
# Out:
#                id                                                url  \
# 0      7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 1      7302327214  https://auburn.craigslist.org/cto/d/auburn-uni...
# 2      7316871204  https://bham.craigslist.org/ctd/d/birmingham-2...
# 3      7316869910  https://bham.craigslist.org/ctd/d/birmingham-2...
# 4      7316868220  https://bham.craigslist.org/ctd/d/birmingham-2...
# ...           ...                                                ...
# 22134  7307323603  https://wyoming.craigslist.org/ctd/d/billings-...
# 22135  7306696334  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 22136  7306692948  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 22137  7306690733  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 22138  7306122308  https://wyoming.craigslist.org/cto/d/burlingto...
#
#            region  price  year manufacturer           model  condition  \
# ...

# %%
df_def = df_def[~df_def['type'].isin(['SUV','van'])]

# %%
df_def.reset_index(inplace=True)

# %%
df_def = df_def.drop('index',axis=1)

# %%
df_def
# Out:
#                id                                                url  \
# 0      7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 1      7316871204  https://bham.craigslist.org/ctd/d/birmingham-2...
# 2      7316735728  https://bham.craigslist.org/ctd/d/bessemer-200...
# 3      7314893113  https://bham.craigslist.org/ctd/d/powder-sprin...
# 4      7314847158  https://bham.craigslist.org/cto/d/birmingham-t...
# ...           ...                                                ...
# 15422  7311718753  https://wyoming.craigslist.org/cto/d/guernsey-...
# 15423  7308982949  https://wyoming.craigslist.org/cto/d/burlingto...
# 15424  7306696334  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15425  7306692948  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15426  7306122308  https://wyoming.craigslist.org/cto/d/burlingto...
#
#            region  price  year manufacturer           model  condition  \
# ...

# %%
df_def['reliability'] = np.nan

df_def.loc[(df_def['manufacturer'] == 'lexus'), 'reliability'] = 95
df_def.loc[(df_def['manufacturer'] == 'subaru'), 'reliability'] = 93
df_def.loc[(df_def['manufacturer'] == 'toyota'), 'reliability'] = 91
df_def.loc[(df_def['manufacturer'] == 'mitsubishi'), 'reliability'] = 89 
df_def.loc[(df_def['manufacturer'] == 'kia'), 'reliability'] = 89
df_def.loc[(df_def['manufacturer'] == 'hyundai'), 'reliability'] = 87
df_def.loc[(df_def['manufacturer'] == 'honda'), 'reliability'] = 87
df_def.loc[(df_def['manufacturer'] == 'mazda'), 'reliability'] = 85
df_def.loc[(df_def['manufacturer'] == 'nissan'), 'reliability'] = 82
df_def.loc[(df_def['manufacturer'] == 'volkswagen'), 'reliability'] = 82
df_def.loc[(df_def['manufacturer'] == 'mercedes-benz'), 'reliability'] = 82
df_def.loc[(df_def['manufacturer'] == 'bmw'), 'reliability'] = 82
df_def.loc[(df_def['manufacturer'] == 'mini'), 'reliability'] = 82
df_def.loc[(df_def['manufacturer'] == 'ford'), 'reliability'] = 80
df_def.loc[(df_def['manufacturer'] == 'audi'), 'reliability'] = 80
df_def.loc[(df_def['manufacturer'] == 'volvo'), 'reliability'] = 80

# %%
df_def
# Out:
#                id                                                url  \
# 0      7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 1      7316871204  https://bham.craigslist.org/ctd/d/birmingham-2...
# 2      7316735728  https://bham.craigslist.org/ctd/d/bessemer-200...
# 3      7314893113  https://bham.craigslist.org/ctd/d/powder-sprin...
# 4      7314847158  https://bham.craigslist.org/cto/d/birmingham-t...
# ...           ...                                                ...
# 15422  7311718753  https://wyoming.craigslist.org/cto/d/guernsey-...
# 15423  7308982949  https://wyoming.craigslist.org/cto/d/burlingto...
# 15424  7306696334  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15425  7306692948  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15426  7306122308  https://wyoming.craigslist.org/cto/d/burlingto...
#
#            region  price  year manufacturer           model  condition  \
# ...

# %%
df_def.to_csv('Datasets/coches_fil.csv',index=False)

# %%
testeo = pd.read_csv('C:/Users/desardi131/Desktop/desardi131/The_Bridge_Data_Science/Python/Proyectos/EDA/Datasets/coches_fil.csv')
testeo
# Out:
#                id                                                url  \
# 0      7313406529  https://auburn.craigslist.org/cto/d/auburn-hon...
# 1      7316871204  https://bham.craigslist.org/ctd/d/birmingham-2...
# 2      7316735728  https://bham.craigslist.org/ctd/d/bessemer-200...
# 3      7314893113  https://bham.craigslist.org/ctd/d/powder-sprin...
# 4      7314847158  https://bham.craigslist.org/cto/d/birmingham-t...
# ...           ...                                                ...
# 15422  7311718753  https://wyoming.craigslist.org/cto/d/guernsey-...
# 15423  7308982949  https://wyoming.craigslist.org/cto/d/burlingto...
# 15424  7306696334  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15425  7306692948  https://wyoming.craigslist.org/ctd/d/cheyenne-...
# 15426  7306122308  https://wyoming.craigslist.org/cto/d/burlingto...
#
#            region  price  year manufacturer           model  condition  \
# ...

# %%
testeo_cond = testeo[(testeo['condition']=='like new') | (testeo['condition']=='excellent')]

# %%
testeo_cyl= testeo_cond[testeo_cond['cylinders']=='4 cylinders']

# %%
testeo_cyl.columns
# Out:
# Index(['id', 'url', 'region', 'price', 'year', 'manufacturer', 'model',
#        'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'state', 'lat', 'long', 'reliability'],
#       dtype='object')

# %%
filtracion = testeo_cyl[['price', 'year','manufacturer','model','condition','fuel','odometer','transmission','drive','size','type','state']]

# %%
filtracion= filtracion.drop_duplicates()

# %%
filtracion = filtracion[filtracion['model']!='fiesta s sedan']

# %%
filtracion = filtracion[ (filtracion['odometer']!=66845.0)]

# %%
filtracion = filtracion[(filtracion['odometer']!= 1.0) & (filtracion['odometer']!=0.0)]

# %%
filtracion = filtracion[(filtracion['odometer'] != 112.0) & (filtracion['odometer']!=173.0) ]

# %%
filtracion =filtracion[(filtracion['odometer']!=1000.0) |(filtracion['model']!='sonata')]

# %%
mejores = filtracion[filtracion.sort_values(by=[ 'year', 'condition','odometer','price'])['drive']=='fwd']
# Out:
# c:\Users\desardi131\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
mejores = mejores.iloc[:,:-1]

# %%
mejores.head(10)
# Out:
#     price  year manufacturer                model  condition    fuel  \
# 3    8900  2013       toyota                prius  excellent  hybrid
# 4   10800  2013       toyota                camry  excellent  hybrid
# 5    5500  2008       nissan               altima   like new     gas
# 7    9990  2015       toyota           corolla le  excellent     gas
# 9    9500  2013      hyundai               sonata  excellent     gas
# 10  11990  2011         audi  a3 tdi premium plus   like new  diesel
# 11   6500  2010        honda         accord coupe   like new     gas
# 12   8500  2011       toyota                camry  excellent     gas
# 13   5999  2013        mazda               sx4 se   like new     gas
# 15  16589  2018         ford               fusion  excellent     gas
#
#     odometer transmission drive       size
# 3   142900.0    automatic   fwd   mid-size
# 4   147000.0    automatic   fwd   mid-size
# 5   150000.0    automatic   fwd        NaN
# ...

# %%
mejores_tot= mejores.head()

# %%
mejores_tot.sort_values('odometer')
# Out:
#    price  year manufacturer       model  condition    fuel  odometer  \
# 9   9500  2013      hyundai      sonata  excellent     gas  125000.0
# 7   9990  2015       toyota  corolla le  excellent     gas  125224.0
# 3   8900  2013       toyota       prius  excellent  hybrid  142900.0
# 4  10800  2013       toyota       camry  excellent  hybrid  147000.0
# 5   5500  2008       nissan      altima   like new     gas  150000.0
#
#   transmission drive      size   type state
# 9    automatic   fwd  mid-size  sedan    al
# 7    automatic   fwd       NaN  sedan    al
# 3    automatic   fwd  mid-size  wagon    al
# 4    automatic   fwd  mid-size  sedan    al
# 5    automatic   fwd       NaN  sedan    al

# %%
mejores['model'].value_counts().head(10)
# Out:
# altima     268
# civic      249
# camry      205
# focus      205
# prius      200
# corolla    199
# accord     197
# sonata     171
# fusion     157
# elantra    153
# Name: model, dtype: int64

# %%
filtracion['drive'].dropna().value_counts()
# Out:
# fwd    6950
# 4wd    1121
# rwd     306
# Name: drive, dtype: int64
